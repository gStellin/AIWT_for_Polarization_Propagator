# %% [markdown]
# # <font color=#DC143C size="+3">Automated generation of Wick's-theorem contributions </font>
# <font color=#9D9D9C size ="+2.25"> at second order in perturbation theory for Gorkov's polarization propagator</font> </br> <font color=#000000 size ="+1">with two one-body interaction vertices</font>

# %% [markdown]
#  ## <font color=#FA8072>Conventions</font>

# %% [markdown]
# <p align="justify">From the application of Wick's theorem to the following matrix element (cf. expansion formula of Gorkov's polarization propagator), </p>

# %% [markdown]
# $\Pi_{acdb}^{g_1g_3g_4g_2}(t,t')\lvert_{\mathrm{second~order}}\equiv -i \left(\frac{-i}{\hbar}\right)^2 \frac{1}{2!}\int\mathrm{d}t_1 \int\mathrm{d}t_2 \langle \Phi_0 \lvert T\{U(t_1) U(t_2) {A_{I}}_a^{g_1}(t){A_{I}}_b^{g_2}(t'){A_{I}}_d^{\dagger g_4}(t') {A_{I}}_c^{\dagger g_3}(t)\}\lvert\Phi_0\rangle_{\mathrm{conn}}$

# %% [markdown]
# the fully-contracted terms consisting of $8$ second-quantization operators are generated. The one-body potential insertions, $U(t_1)$ and $U(t_2)$, take the form

# %% [markdown]
# $U(t_1) = \frac{1}{2}\sum_{ef}[u_{ef}^{11}{a_I}_e^{\dagger}(t_1){a_I}_f(t_1)+u_{ef}^{22}{a_I}_{\bar{e}}(t_1){a_I}_{\bar{f}}^{\dagger}(t_1)+u_{ef}^{12}{a_I}_e^{\dagger}(t_1){a_I}_{\bar{f}}^{\dagger}(t_1)+u_{ef}^{21}{a_I}_{\bar{e}}(t_1){a_I}_f(t_1)]~,$

# %% [markdown]
# $U(t_2) = \frac{1}{2}\sum_{gh}[u_{gh}^{11}{a_I}_g^{\dagger}(t_2){a_I}_h(t_2)+u_{gh}^{22}{a_I}_{\bar{g}}(t_2){a_I}_{\bar{h}}^{\dagger}(t_2)+u_{gh}^{12}{a_I}_g^{\dagger}(t_2){a_I}_{\bar{h}}^{\dagger}(t_2)+u_{gh}^{21}{a_I}_{\bar{g}}(t_2){a_I}_h(t_2)]~.$

# %% [markdown]
# <p align="justify">Due to the presence of two one-body interaction vertices, the number of distinct fully-contracted terms corresponds to $7!! = 105$. The results of the generation process hold identically for all the $4$ Nambu components of the one-body potential and are the same for each of the $16$ Nambu components of Gorkov's polarization propagator.  A significant part of these Wick's-theorem contributions has to be discarded, since it corresponds either to disconnected diagrams or to exchange diagrams that are cancelled by the subtractive term of the polarization propagator.  At second order, no conjoint diagram containing two one-body interaction vertices exists. Additionally, since the one-body potential is not invariant under permutation of the two indices, the filtration process accounts only for inter-vertex transpositions of single-particle indices.</p>

# %%
7*5*3*1
# Out:
# 105

# %% [markdown]
# The alphabetic single-particle indices of the second-quantization operators are converted into positive integers by means of the following map:

# %% [markdown]
# <table>
#     <tr>
#         <th> e </th>
#         <th> f </th>
#         <th> g </th>
#         <th> h </th>
#         <th> a </th>
#         <th> b </th>
#         <th> d </th>
#         <th> c </th>
#     </tr>
#     <tr>
#         <th> 1 </th>
#         <th> 2 </th>
#         <th> 3 </th>
#         <th> 4 </th>
#         <th> 5 </th>
#         <th> 6 </th>
#         <th> 7 </th>
#         <th> 8 </th>
#     </tr>
# </table>

# %% [markdown]
# as such, the single particle indices are stored into arrays (cf. 'Acomb', 'Acombsort', 'AdisjBogoDiag' et c.).

# %% [markdown]
#  ## <font color=#FA8072>Generation of the first-order fully-contracted terms</font>

# %% [markdown]
# The second-order fully-contracted terms are found to be $105$ in total, consistently with the formula $4n+2m+3!!$ with $n=0$ and $m=2$. Binary contractions belonging to the same fully contracted term (index i in the array initialization) are denoted by the index $j$. The two single particle indices within the same contraction are distinguished by the index $k$. The process produces no repeated pairs, by construction.

# %%
l = 1;
Acomb = Table[0, {i, 1, 150}, {j, 1, 4}, {k, 1, 2}];
Acomb[[l]] = {{1, 2}, {3, 4}, {5, 6}, {7, 8}};
For[g = 1, g <= 7, g++,
  growind = 1;
  gcolind = 2;
  For[h = 1, h <= 5, h++,
   hrowind = 2;
   hcolind = 2;
   For[i = 1, i <= 3, i++,
    irowind = 3;
    icolind = 2;
    Acomb[[l]] = Acomb[[1]];
    If[g != 1,
     growpiv = Floor[g/2] + 1;
     gcolpiv = - Floor[g/2] + Ceiling[g/2] + 1;
     Acomb[[l, growind, gcolind]] = Acomb[[1, growpiv, gcolpiv]];
     Acomb[[l, growpiv, gcolpiv]] = Acomb[[1, growind, gcolind]]];
    If[h != 1,
     hrowpiv = Floor[h/2] + 2;
     hcolpiv = - Floor[h/2] + Ceiling[h/2] + 1;
     Atemp1 = Acomb[[l, hrowind, hcolind]];
     Atemp2 = Acomb[[l, hrowpiv, hcolpiv]];
     Acomb[[l, hrowind, hcolind]] = Atemp2;
     Acomb[[l, hrowpiv, hcolpiv]] = Atemp1];
    If[i != 1,
     irowpiv = Floor[i/2] + 3;
     icolpiv = - Floor[i/2] + Ceiling[i/2] + 1;
     Atemp1 = Acomb[[l, irowind, icolind]];
     Atemp2 = Acomb[[l, irowpiv, icolpiv]];
     Acomb[[l, irowind, icolind]] = Atemp2;
     Acomb[[l, irowpiv, icolpiv]] = Atemp1];
    l++]];
  If[g == 7, 
   Print["Loop ", g, " completed and ", l - 1, 
    " Wick's-theorem contributions generated."]]];
# Out:
# Loop 7 completed and 105 Wick's-theorem contributions generated.

# %% [markdown]
# Sorting code for the generated fully-contracted terms. Single-particle indices within the same contraction are sorted in ascending order.

# %%
Acombsort = Table[0, {i, 1, 105}, {j, 1, 4}, {k, 1, 2}];
For[s = 1, s <= 105, s++,
  If[Acomb[[s, 1, 1]] > Acomb[[s, 1, 2]],
   Acombsort[[s, 1, 1]] = Acomb[[s, 1, 2]];
   Acombsort[[s, 1, 2]] = Acomb[[s, 1, 1]],
   Acombsort[[s, 1]] = Acomb[[s, 1]];];
  If[Acomb[[s, 2, 1]] > Acomb[[s, 2, 2]],
   Acombsort[[s, 2, 1]] = Acomb[[s, 2, 2]];
   Acombsort[[s, 2, 2]] = Acomb[[s, 2, 1]],
   Acombsort[[s, 2]] = Acomb[[s, 2]];];
  If[Acomb[[s, 3, 1]] > Acomb[[s, 3, 2]],
   Acombsort[[s, 3, 1]] = Acomb[[s, 3, 2]];
   Acombsort[[s, 3, 2]] = Acomb[[s, 3, 1]],
   Acombsort[[s, 3]] = Acomb[[s, 3]];];
  If[Acomb[[s, 4, 1]] > Acomb[[s, 4, 2]],
   Acombsort[[s, 4, 1]] = Acomb[[s, 4, 2]];
   Acombsort[[s, 4, 2]] = Acomb[[s, 4, 1]],
   Acombsort[[s, 4]] = Acomb[[s, 4]];];];

# %% [markdown]
# # <font color=#71797E>Disjoint Diagrams</font>

# %% [markdown]
# The disjoint  diagrams at second order are $72$ in total. These are distributed as follows: <br>
# i) $8$ Bogoliubov diagrams dressed in the antidiagonal; <br>
# ii) $8$ Bogoliubov diagrams dressed in the diagonal; <br>
# iii) $8$ Bogoliubov diagrams dressed in both the diagonal and the antidiagonal; <br>
# iv) $8$ Direct diagrams dressed in the left propagator; <br>
# v) $8$ Direct diagrams dressed in the right propagator; <br>
# vi) $8$ Direct diagrams dressed in both the left and the right propagator; <br>
# vii) $8$ Exchange diagrams dressed in the propagator above; <br>
# viii) $8$ Exchange diagrams dressed in the propagator below; <br>
# ix) $8$ Exchange diagrams dressed in both the above and below propagator; <br>

# %%
AdisjBogoDiag = Table[0, {i, 1, 72}, {j, 1, 4}, {k, 1, 2}];
AdisjBogoAntidiag = Table[0, {i, 1, 72}, {j, 1, 4}, {k, 1, 2}];
AdisjBogoliubov = Table[0, {i, 1, 72}, {j, 1, 4}, {k, 1, 2}];
AdisjDirLeft = Table[0, {i, 1, 72}, {j, 1, 4}, {k, 1, 2}];
AdisjDirRight = Table[0, {i, 1, 72}, {j, 1, 4}, {k, 1, 2}];
AdisjDirect = Table[0, {i, 1, 72}, {j, 1, 4}, {k, 1, 2}];
AdisjExchAbove = Table[0, {i, 1, 72}, {j, 1, 4}, {k, 1, 2}];
AdisjExchBelow = Table[0, {i, 1, 72}, {j, 1, 4}, {k, 1, 2}];
AdisjExchange = Table[0, {i, 1, 72}, {j, 1, 4}, {k, 1, 2}];
l = 1;
m = 1;
n = 1;
o = 1;
p = 1;
q = 1;
r = 1;
s = 1;
t = 1;
For[i = 1, i <= 105, i++,
 Link12 = False; 
 DiscV1 = False;
 DiscV2 = False;
 Conn5V1 = False;
 Conn5V2 = False;
 Conn6V1 = False;
 Conn6V2 = False;
 Conn7V1 = False;
 Conn7V2 = False;
 Conn8V1 = False;
 Conn8V2 = False;
 Bridge56 = False;
 Bridge57 = False;
 Bridge58 = False;
 Bridge67 = False;
 Bridge68 = False;
 Bridge78 = False;
 SelfBinding12 = False;
 SelfBinding34 = False;
 For[j = 1, j <= 4, j++,
   If[Acombsort[[i, j]] == {5, 6}, Bridge56 = True];
  If[Acombsort[[i, j]] == {5, 7}, Bridge57 = True];
  If[Acombsort[[i, j]] == {5, 8}, Bridge58 = True];
  If[Acombsort[[i, j]] == {6, 7}, Bridge67 = True];
  If[Acombsort[[i, j]] == {6, 8}, Bridge68 = True];
  If[Acombsort[[i, j]] == {7, 8}, Bridge78 = True];
  If[Acombsort[[i, j]] == {1, 2}  , SelfBinding12 = True];
  If[Acombsort[[i, j]] == {3, 4}  , SelfBinding34 = True];
  If[Acombsort[[i, j]] == {1, 3} || Acombsort[[i, j]] == {1, 4} || 
    Acombsort[[i, j]] == {2, 3} || Acombsort[[i, j]] == {2, 4} , 
   Link12 = True;];
  ];
 If[SelfBinding12 == True , DiscV1 = True];
 If[SelfBinding34 == True , DiscV2 = True];
 If[Bridge56 == False && Bridge57 == False && Bridge58 == False && 
   Bridge67 == False && Bridge68 == False && Bridge78 == False && 
   DiscV1 == False && DiscV2 == False,
  For[j = 1, j <= 4, j++,
    If[Link12 == False,
      If[Acombsort[[i, j]] == {1, 5} || Acombsort[[i, j]] == {2, 5} , 
       Conn5V1 = True];
      If[Acombsort[[i, j]] == {1, 6} || Acombsort[[i, j]] == {2, 6} , 
       Conn6V1 = True];
      If[Acombsort[[i, j]] == {1, 7} || Acombsort[[i, j]] == {2, 7} , 
       Conn7V1 = True];
      If[Acombsort[[i, j]] == {1, 8} || Acombsort[[i, j]] == {2, 8} , 
       Conn8V1 = True];
      If[Acombsort[[i, j]] == {3, 5} || Acombsort[[i, j]] == {4, 5} , 
       Conn5V2 = True];
      If[Acombsort[[i, j]] == {3, 6} || Acombsort[[i, j]] == {4, 6} , 
       Conn6V2 = True];
      If[Acombsort[[i, j]] == {3, 7} || Acombsort[[i, j]] == {4, 7} , 
       Conn7V2 = True];
      If[Acombsort[[i, j]] == {3, 8} || Acombsort[[i, j]] == {4, 8} , 
       Conn8V2 = True];
      ];
    ];
  ]; 
 If[Conn5V2 == True && Conn6V2 == True && Conn7V2 == False && 
   Conn8V2 == False && Conn5V1 == False && Conn6V1 == False && 
   Conn7V1 == True && Conn8V1 == True, 
  AdisjBogoliubov[[n]] = Acombsort[[i]]; n++];
 If[Conn5V1 == True && Conn6V1 == True && Conn7V1 == False && 
   Conn8V1 == False && Conn5V2 == False && Conn6V2 == False && 
   Conn7V2 == True && Conn8V2 == True, 
  AdisjBogoliubov[[n]] = Acombsort[[i]]; n++];
 If[Conn5V2 == True && Conn6V2 == False && Conn7V2 == True && 
   Conn8V2 == False && Conn5V1 == False && Conn6V1 == True && 
   Conn7V1 == False && Conn8V1 == True, 
  AdisjDirect[[q]] = Acombsort[[i]]; q++];
 If[Conn5V1 == True && Conn6V1 == False && Conn7V1 == True && 
   Conn8V1 == False && Conn5V2 == False && Conn6V2 == True && 
   Conn7V2 == False && Conn8V2 == True, 
  AdisjDirect[[q]] = Acombsort[[i]]; q++];
 If[Conn5V2 == True && Conn6V2 == False && Conn7V2 == False && 
   Conn8V2 == True && Conn5V1 == False && Conn6V1 == True && 
   Conn7V1 == True && Conn8V1 == False, 
  AdisjExchange[[t]] = Acombsort[[i]]; t++];
 If[Conn5V1 == True && Conn6V1 == False && Conn7V1 == False && 
   Conn8V1 == True && Conn5V2 == False && Conn7V2 == True && 
   Conn7V2 == True && Conn8V2 == False, 
  AdisjExchange[[t]] = Acombsort[[i]]; t++];
 If[Link12 == True && Bridge57 == True && Bridge68 == False, 
  AdisjDirRight[[p]] = Acombsort[[i]]; p++];
 If[Link12 == True && Bridge57 == False && Bridge68 == True, 
  AdisjDirLeft[[o]] = Acombsort[[i]]; o++];
 If[Link12 == True &&  Bridge56 == True && Bridge78 == False, 
  AdisjBogoAntidiag[[l]] = Acombsort[[i]]; l++];
 If[Link12 == True && Bridge56 == False && Bridge78 == True, 
  AdisjBogoDiag[[m]] = Acombsort[[i]]; m++];
 If[Link12 == True && Bridge58 == False && Bridge67 == True, 
  AdisjExchAbove[[r]] = Acombsort[[i]]; r++];
 If[ Link12 == True && Bridge58 == True && Bridge67 == False, 
  AdisjExchBelow[[s]] = Acombsort[[i]]; s++];
 If[i == 105, 
  Print["Loop ", i, " completed and ", l - 1, 
   " antidiagonally-dressed Bogoliubov contributions found."] ];
 If[i == 105, 
  Print["Loop ", i, " completed and ", m - 1, 
   " diagonally-dressed Bogoliubov contributions found."] ];
 If[ i == 105, 
  Print["Loop ", i, " completed and ", n - 1, 
   " diagonally-and-antidiagonally-dressed Bogoliubov contributions found."] ];
 If[i == 105, 
  Print["Loop ", i, " completed and ", r - 1, 
   " above-dressed exchange contributions found."] ];
 If[i == 105, 
  Print["Loop ", i, " completed and ", s - 1, 
   " below-dressed exchange contributions found."] ];
 If[i == 105, 
  Print["Loop ", i, " completed and ", t - 1, 
   " above-and-below-dressed exchange contributions found."] ];
 If[i == 105, 
  Print["Loop ", i, " completed and ", o - 1, 
   " left-dressed direct contributions found."] ];
 If[i == 105, 
  Print["Loop ", i, " completed and ", p - 1, 
   " right-dressed direct contributions found."] ];
 If[i == 105, 
  Print["Loop ", i, " completed and ", q - 1, 
   " left-and-right-dressed direct contributions found."] ];]
# Out:
# Loop 105 completed and 8 antidiagonally-dressed Bogoliubov contributions\
#
# >    found.
# Loop 105 completed and 8 diagonally-dressed Bogoliubov contributions found.
# Loop 105 completed and 8 diagonally-and-antidiagonally-dressed Bogoliubov\
#
# >    contributions found.
# Loop 105 completed and 8 above-dressed exchange contributions found.
# Loop 105 completed and 8 below-dressed exchange contributions found.
# Loop 105 completed and 8 above-and-below-dressed exchange contributions found.
# Loop 105 completed and 8 left-dressed direct contributions found.
# Loop 105 completed and 8 right-dressed direct contributions found.
# Loop 105 completed and 8 left-and-right-dressed direct contributions found.

# %% [markdown]
#  ## <font color=#FA8072>Disjoint direct diagrams with dressed single-particle propagator on the left</font>

# %% [markdown]
# Direct diagrams with unperturbed 1-body propagator on the right are processed. Their initial number is $8$ in total.

# %% [markdown]
# ### <font color=#E9967A>Left-dressed disjoint direct diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent left-dressed disjoint direct contributions with non-identical vertices at second order remains equal to $8$.

# %%
For[u = 1, u <= 8, u++, Print["CombDirLeft[[", u, "]]=", AdisjDirLeft[[u]], ";"]];
# Out:
# CombDirLeft[[1]]={{1, 3}, {2, 5}, {4, 7}, {6, 8}};
# CombDirLeft[[2]]={{1, 3}, {2, 7}, {4, 5}, {6, 8}};
# CombDirLeft[[3]]={{1, 4}, {3, 5}, {2, 7}, {6, 8}};
# CombDirLeft[[4]]={{1, 4}, {3, 7}, {2, 5}, {6, 8}};
# CombDirLeft[[5]]={{1, 5}, {2, 3}, {4, 7}, {6, 8}};
# CombDirLeft[[6]]={{1, 5}, {3, 7}, {2, 4}, {6, 8}};
# CombDirLeft[[7]]={{1, 7}, {3, 5}, {2, 4}, {6, 8}};
# CombDirLeft[[8]]={{1, 7}, {2, 3}, {4, 5}, {6, 8}};

# %%
For[u = 1, u <= 8, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;

# %% [markdown]
# There are only $8$ second-order left-dressed disjoint direct diagrams with non-identical one-body vertices. The multiplicity check is fulfilled by construction.

# %% [markdown]
# ### <font color=#E9967A>Left-dressed disjoint direct diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $4$ inequivalent fully-contracted terms corresponding to left-dressed disjoint direct diagrams are found.

# %%
AdcdlVertex = Table[0, {i, 1, 8}, {j, 1, 4}, {k, 1, 2}];
MultdcdlVertex = Table[0, {i, 1, 8}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 4}, {k, 1, 4}];

s = 1;
AdcdlVertex[[1]] = AdisjDirLeft[[1]];
MultdcdlVertex[[1]] = 1;
For[u = 1, u <= 8, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = AdisjDirLeft[[u, i, j]];
   If[AdisjDirLeft[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[AdisjDirLeft[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[AdisjDirLeft[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[AdisjDirLeft[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[AdisjDirLeft[[u, i, j]] >= 5, 
    Temp[[2, i, j]] = AdisjDirLeft[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdcdlVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdcdlVertex[[v]] = MultdcdlVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; AdcdlVertex[[s]] = AdisjDirLeft[[u]]; 
   MultdcdlVertex[[v]] = 1];
  ];
 If[u == 8, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent left-dressed direct contributions found."]];
 ]
# Out:
# Loop 8 completed and 4 inequivalent left-dressed direct contributions found.

# %%
For[u = 1, u <= 4, u++, Print["CombDirLeft[[", u, "]]=", AdcdlVertex[[u]], ";"]];
# Out:
# CombDirLeft[[1]]={{1, 3}, {2, 5}, {4, 7}, {6, 8}};
# CombDirLeft[[2]]={{1, 4}, {3, 5}, {2, 7}, {6, 8}};
# CombDirLeft[[3]]={{1, 4}, {3, 7}, {2, 5}, {6, 8}};
# CombDirLeft[[4]]={{1, 5}, {3, 7}, {2, 4}, {6, 8}};

# %%
For[u = 1, u <= 4, u++, Print["GGFMult[[", u, "]]=", MultdcdlVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=2;
# GGFMult[[2]]=2;
# GGFMult[[3]]=2;
# GGFMult[[4]]=2;

# %% [markdown]
# There are only $4$ inequivalent second-order left-dressed disjoint direct diagrams with two identical one-body vertices. The multiplicity check is fulfilled.

# %%
Sum[MultdcdlVertex[[u]], {u, 1, 4}]
# Out:
# 8

# %% [markdown]
#  ## <font color=#FA8072>Disjoint direct diagrams with dressed single-particle propagator on the right</font>

# %% [markdown]
# Direct diagrams with unperturbed 1-body propagator on the left are processed. Their initial number is $8$ in total.

# %% [markdown]
# ### <font color=#E9967A>Right-dressed disjoint direct diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent right-dressed disjoint direct contributions with non-identical vertices at second order remains equal to $8$.

# %%
For[u = 1, u <= 8, u++, Print["CombDirRight[[", u, "]]=", AdisjDirRight[[u]], ";"]];
# Out:
# CombDirRight[[1]]={{1, 3}, {2, 6}, {5, 7}, {4, 8}};
# CombDirRight[[2]]={{1, 3}, {2, 8}, {5, 7}, {4, 6}};
# CombDirRight[[3]]={{1, 4}, {3, 6}, {5, 7}, {2, 8}};
# CombDirRight[[4]]={{1, 4}, {3, 8}, {5, 7}, {2, 6}};
# CombDirRight[[5]]={{1, 6}, {2, 3}, {5, 7}, {4, 8}};
# CombDirRight[[6]]={{1, 6}, {3, 8}, {5, 7}, {2, 4}};
# CombDirRight[[7]]={{1, 8}, {3, 6}, {5, 7}, {2, 4}};
# CombDirRight[[8]]={{1, 8}, {2, 3}, {5, 7}, {4, 6}};

# %%
For[u = 1, u <= 8, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;

# %% [markdown]
# There are only $8$ second-order right-dressed disjoint direct diagrams with non-identical one-body vertices. The multiplicity check is fulfilled by construction.

# %% [markdown]
# ### <font color=#E9967A>Right-dressed disjoint direct diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $4$ inequivalent fully-contracted terms corresponding to right-dressed disjoint direct diagrams are found.

# %%
AdcdrVertex = Table[0, {i, 1, 8}, {j, 1, 4}, {k, 1, 2}];
MultdcdrVertex = Table[0, {i, 1, 8}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 4}, {k, 1, 4}];

s = 1;
AdcdrVertex[[1]] = AdisjDirRight[[1]];
MultdcdrVertex[[1]] = 1;
For[u = 1, u <= 8, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = AdisjDirRight[[u, i, j]];
   If[AdisjDirRight[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[AdisjDirRight[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[AdisjDirRight[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[AdisjDirRight[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[AdisjDirRight[[u, i, j]] >= 5, 
    Temp[[2, i, j]] = AdisjDirRight[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdcdrVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdcdrVertex[[v]] = MultdcdrVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; AdcdrVertex[[s]] = AdisjDirRight[[u]]; 
   MultdcdrVertex[[v]] = 1];
  ];
 If[u == 8, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent right-dressed direct contributions found."]];
 ]
# Out:
# Loop 8 completed and 4 inequivalent right-dressed direct contributions found.

# %%
For[u = 1, u <= 4, u++, Print["CombDirRight[[", u, "]]=", AdcdrVertex[[u]], ";"]];
# Out:
# CombDirRight[[1]]={{1, 3}, {2, 6}, {5, 7}, {4, 8}};
# CombDirRight[[2]]={{1, 4}, {3, 6}, {5, 7}, {2, 8}};
# CombDirRight[[3]]={{1, 4}, {3, 8}, {5, 7}, {2, 6}};
# CombDirRight[[4]]={{1, 6}, {3, 8}, {5, 7}, {2, 4}};

# %%
For[u = 1, u <= 4, u++, Print["GGFMult[[", u, "]]=", MultdcdrVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=2;
# GGFMult[[2]]=2;
# GGFMult[[3]]=2;
# GGFMult[[4]]=2;

# %% [markdown]
# There are only $4$ inequivalent second-order right-dressed disjoint direct diagrams with identical one-body vertices. The multiplicity check is fulfilled.

# %%
Sum[MultdcdrVertex[[u]], {u, 1, 4}]
# Out:
# 8

# %% [markdown]
#  ## <font color=#FA8072>Disjoint direct diagrams with left-and-right-dressed single-particle propagators</font>

# %% [markdown]
# Direct diagrams with perturbed 1-body propagators on the left and the right are processed. Their initial number is $8$ in total.

# %% [markdown]
# ### <font color=#E9967A>Left-and-right-dressed disjoint direct diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent left-and-right-dressed disjoint direct contributions with non-identical vertices at second order remains equal to $8$.

# %%
For[u = 1, u <= 8, u++, 
  Print["CombDir[[", u, "]]=", AdisjDirect[[u]], ";"]];
# Out:
# CombDir[[1]]={{1, 5}, {3, 6}, {2, 7}, {4, 8}};
# CombDir[[2]]={{1, 5}, {3, 8}, {2, 7}, {4, 6}};
# CombDir[[3]]={{1, 6}, {3, 5}, {4, 7}, {2, 8}};
# CombDir[[4]]={{1, 6}, {3, 7}, {4, 5}, {2, 8}};
# CombDir[[5]]={{1, 7}, {3, 6}, {2, 5}, {4, 8}};
# CombDir[[6]]={{1, 7}, {3, 8}, {2, 5}, {4, 6}};
# CombDir[[7]]={{1, 8}, {3, 5}, {4, 7}, {2, 6}};
# CombDir[[8]]={{1, 8}, {3, 7}, {4, 5}, {2, 6}};

# %%
For[u = 1, u <= 8, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;

# %% [markdown]
# There are only $8$ second-order left-and-right-dressed disjoint direct diagrams with non-identical one-body vertices. The multiplicity check is fulfilled by construction.

# %% [markdown]
# ### <font color=#E9967A>Left-and-right-dressed disjoint direct diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $4$ inequivalent fully-contracted terms corresponding to left-and-right-dressed disjoint direct diagrams are found.

# %%
AdcdVertex = Table[0, {i, 1, 8}, {j, 1, 4}, {k, 1, 2}];
MultdcdVertex = Table[0, {i, 1, 8}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 2}, {k, 1, 4}];

s = 1;
AdcdVertex[[1]] = AdisjDirect[[1]];
MultdcdVertex[[1]] = 1;
For[u = 1, u <= 8, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = AdisjDirect[[u, i, j]];
   If[AdisjDirect[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[AdisjDirect[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[AdisjDirect[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[AdisjDirect[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[AdisjDirect[[u, i, j]] >= 5, 
    Temp[[2, i, j]] = AdisjDirect[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdcdVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdcdVertex[[v]] = MultdcdVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; AdcdVertex[[s]] = AdisjDirect[[u]]; 
   MultdcdVertex[[v]] = 1];
  ];
 If[u == 8, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent left-and-right-dressed direct contributions found."]];
 ]
# Out:
# Loop 8 completed and 4 inequivalent left-and-right-dressed direct\
#
# >    contributions found.

# %%
For[u = 1, u <= 4, u++, Print["CombDir[[", u, "]]=", AdcdVertex[[u]], ";"]];
# Out:
# CombDir[[1]]={{1, 5}, {3, 6}, {2, 7}, {4, 8}};
# CombDir[[2]]={{1, 5}, {3, 8}, {2, 7}, {4, 6}};
# CombDir[[3]]={{1, 6}, {3, 7}, {4, 5}, {2, 8}};
# CombDir[[4]]={{1, 7}, {3, 8}, {2, 5}, {4, 6}};

# %%
For[u = 1, u <= 4, u++, Print["GGFMult[[", u, "]]=", MultdcdVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=2;
# GGFMult[[2]]=2;
# GGFMult[[3]]=2;
# GGFMult[[4]]=2;

# %% [markdown]
# There are only $4$ inequivalent second-order left-and-right-dressed disjoint direct diagrams with identical one-body vertices. The multiplicity check is fulfilled.

# %%
Sum[MultdcdVertex[[u]], {u, 1, 4}]
# Out:
# 8

# %% [markdown]
# ## <font color=#FA8072>Disjoint exchange diagrams with dressed single-particle propagator above</font>

# %% [markdown]
# Exchange diagrams with unperturbed 1-body propagator below are processed. Their initial number is $8$ in total.

# %% [markdown]
# ### <font color=#E9967A>Above-dressed disjoint exchange diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent above-dressed disjoint exchange contributions with non-identical vertices at second order remains equal to $8$.

# %%
For[u = 1, u <= 8, u++, Print["CombExcAbove[[", u, "]]=", AdisjExchAbove[[u]], ";"]];
# Out:
# CombExcAbove[[1]]={{1, 3}, {2, 5}, {4, 8}, {6, 7}};
# CombExcAbove[[2]]={{1, 3}, {2, 8}, {4, 5}, {6, 7}};
# CombExcAbove[[3]]={{1, 4}, {3, 5}, {2, 8}, {6, 7}};
# CombExcAbove[[4]]={{1, 4}, {3, 8}, {2, 5}, {6, 7}};
# CombExcAbove[[5]]={{1, 5}, {2, 3}, {4, 8}, {6, 7}};
# CombExcAbove[[6]]={{1, 5}, {3, 8}, {2, 4}, {6, 7}};
# CombExcAbove[[7]]={{1, 8}, {3, 5}, {2, 4}, {6, 7}};
# CombExcAbove[[8]]={{1, 8}, {2, 3}, {4, 5}, {6, 7}};

# %%
For[u = 1, u <= 8, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;

# %% [markdown]
# There are only $8$ second-order above-dressed disjoint exchange diagrams with non-identical one-body vertices. The multiplicity check is fulfilled by construction.

# %% [markdown]
# ### <font color=#E9967A>Above-dressed disjoint exchange diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $4$ inequivalent fully-contracted terms corresponding to above-dressed disjoint exchange diagrams are found.

# %%
AdceaVertex = Table[0, {i, 1, 8}, {j, 1, 4}, {k, 1, 2}];
MultdceaVertex = Table[0, {i, 1, 8}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 2}, {k, 1, 4}];

s = 1;
AdceaVertex[[1]] = AdisjExchAbove[[1]];
MultdceaVertex[[1]] = 1;
For[u = 1, u <= 8, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = AdisjExchAbove[[u, i, j]];
   If[AdisjExchAbove[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[AdisjExchAbove[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[AdisjExchAbove[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[AdisjExchAbove[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[AdisjExchAbove[[u, i, j]] >= 5, 
    Temp[[2, i, j]] = AdisjExchAbove[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdceaVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdceaVertex[[v]] = MultdceaVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; AdceaVertex[[s]] = AdisjExchAbove[[u]]; 
   MultdceaVertex[[v]] = 1];
  ];
 If[u == 8, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent above-dressed exchange contributions found."]];
 ]
# Out:
# Loop 8 completed and 4 inequivalent above-dressed exchange contributions\
#
# >    found.

# %%
For[u = 1, u <= 4, u++, 
  Print["CombExchAbove[[", u, "]]=", AdceaVertex[[u]], ";"]];
# Out:
# CombExchAbove[[1]]={{1, 3}, {2, 5}, {4, 8}, {6, 7}};
# CombExchAbove[[2]]={{1, 4}, {3, 5}, {2, 8}, {6, 7}};
# CombExchAbove[[3]]={{1, 4}, {3, 8}, {2, 5}, {6, 7}};
# CombExchAbove[[4]]={{1, 5}, {3, 8}, {2, 4}, {6, 7}};

# %%
For[u = 1, u <= 4, u++, 
  Print["GGFMult[[", u, "]]=", MultdceaVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=2;
# GGFMult[[2]]=2;
# GGFMult[[3]]=2;
# GGFMult[[4]]=2;

# %% [markdown]
# There are only $4$ inequivalent second-order above-dressed disjoint exchange diagrams with identical one-body vertices. The multiplicity check is fulfilled.

# %%
Sum[MultdceaVertex[[u]], {u, 1, 4}]
# Out:
# 8

# %% [markdown]
# ## <font color=#FA8072>Disjoint exchange diagrams with dressed single-particle propagator below</font>

# %% [markdown]
# Exchange diagrams with unperturbed 1-body propagator above are processed. Their initial number is 8 in total.

# %% [markdown]
# ### <font color=#E9967A>Below-dressed disjoint exchange diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent below-dressed disjoint exchange contributions with non-identical vertices at second order remains equal to $8$.

# %%
For[u = 1, u <= 8, u++, Print["CombExcBelow[[", u, "]]=", AdisjExchBelow[[u]], ";"]];
# Out:
# CombExcBelow[[1]]={{1, 3}, {2, 6}, {5, 8}, {4, 7}};
# CombExcBelow[[2]]={{1, 3}, {2, 7}, {5, 8}, {4, 6}};
# CombExcBelow[[3]]={{1, 4}, {3, 6}, {5, 8}, {2, 7}};
# CombExcBelow[[4]]={{1, 4}, {3, 7}, {5, 8}, {2, 6}};
# CombExcBelow[[5]]={{1, 6}, {2, 3}, {5, 8}, {4, 7}};
# CombExcBelow[[6]]={{1, 6}, {3, 7}, {5, 8}, {2, 4}};
# CombExcBelow[[7]]={{1, 7}, {3, 6}, {5, 8}, {2, 4}};
# CombExcBelow[[8]]={{1, 7}, {2, 3}, {5, 8}, {4, 6}};

# %%
For[u = 1, u <= 8, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;

# %% [markdown]
# There are only $8$ second-order below-dressed disjoint exchange diagrams with non-identical one-body vertices. The multiplicity check is fulfilled by construction.

# %% [markdown]
# ### <font color=#E9967A>Below-dressed disjoint exchange diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $4$ inequivalent fully-contracted terms corresponding to below-dressed disjoint exchange diagrams are found.

# %%
AdcebVertex = Table[0, {i, 1, 8}, {j, 1, 4}, {k, 1, 2}];
MultdcebVertex = Table[0, {i, 1, 8}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 2}, {k, 1, 4}];

s = 1;
AdcebVertex[[1]] = AdisjExchBelow[[1]];
MultdcebVertex[[1]] = 1;
For[u = 1, u <= 8, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = AdisjExchBelow[[u, i, j]];
   If[AdisjExchBelow[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[AdisjExchBelow[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[AdisjExchBelow[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[AdisjExchBelow[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[AdisjExchBelow[[u, i, j]] >= 5, 
    Temp[[2, i, j]] = AdisjExchBelow[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdcebVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdcebVertex[[v]] = MultdcebVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; AdcebVertex[[s]] = AdisjExchBelow[[u]]; 
   MultdcebVertex[[v]] = 1];
  ];
 If[u == 8, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent below-dressed exchange contributions found."]];
 ]
# Out:
# Loop 8 completed and 4 inequivalent below-dressed exchange contributions\
#
# >    found.

# %%
For[u = 1, u <= 4, u++, Print["CombExcBelow[[", u, "]]=", AdcebVertex[[u]], ";"]];
# Out:
# CombExcBelow[[1]]={{1, 3}, {2, 6}, {5, 8}, {4, 7}};
# CombExcBelow[[2]]={{1, 4}, {3, 6}, {5, 8}, {2, 7}};
# CombExcBelow[[3]]={{1, 4}, {3, 7}, {5, 8}, {2, 6}};
# CombExcBelow[[4]]={{1, 6}, {3, 7}, {5, 8}, {2, 4}};

# %%
For[u = 1, u <= 4, u++, Print["GGFMult[[", u, "]]=", MultdcebVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=2;
# GGFMult[[2]]=2;
# GGFMult[[3]]=2;
# GGFMult[[4]]=2;

# %% [markdown]
# There are only $8$ inequivalent second-order below-dressed disjoint exchange diagrams with identical one-body vertices. The multiplicity check is fulfilled.

# %%
Sum[MultdcebVertex[[u]], {u, 1, 4}]
# Out:
# 8

# %% [markdown]
# ## <font color=#FA8072>Disjoint exchange diagrams with dressed single-particle propagators above and below</font>

# %% [markdown]
# Exchange diagrams with unperturbed 1-body propagators above and below are processed. Their initial number is $8$ in total.

# %% [markdown]
# ### <font color=#E9967A>Above-and-below-dressed disjoint exchange diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent above-and-below-dressed disjoint exchange contributions with non-identical vertices at second order remains equal to $8$.

# %%
For[u = 1, u <= 8, u++, Print["CombExc[[", u, "]]=", AdisjExchange[[u]], ";"]];
# Out:
# CombExc[[1]]={{1, 5}, {3, 6}, {2, 8}, {4, 7}};
# CombExc[[2]]={{1, 5}, {3, 7}, {2, 8}, {4, 6}};
# CombExc[[3]]={{1, 6}, {3, 5}, {4, 8}, {2, 7}};
# CombExc[[4]]={{1, 6}, {3, 8}, {4, 5}, {2, 7}};
# CombExc[[5]]={{1, 7}, {3, 5}, {4, 8}, {2, 6}};
# CombExc[[6]]={{1, 7}, {3, 8}, {4, 5}, {2, 6}};
# CombExc[[7]]={{1, 8}, {3, 6}, {2, 5}, {4, 7}};
# CombExc[[8]]={{1, 8}, {3, 7}, {2, 5}, {4, 6}};

# %%
For[u = 1, u <= 8, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;

# %% [markdown]
# There are only $8$ second-order below-dressed disjoint exchange diagrams with non-identical one-body vertices. The multiplicity check is fulfilled by construction.

# %% [markdown]
# ### <font color=#E9967A>Above-and-below-dressed disjoint exchange diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $4$ inequivalent fully-contracted terms corresponding to above-and-below-dressed disjoint exchange diagrams are found.

# %%
AdceVertex = Table[0, {i, 1, 8}, {j, 1, 4}, {k, 1, 2}];
MultdceVertex = Table[0, {i, 1, 8}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 2}, {k, 1, 4}];

s = 1;
AdceVertex[[1]] = AdisjExchange[[1]];
MultdceVertex[[1]] = 1;
For[u = 1, u <= 8, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = AdisjExchange[[u, i, j]];
   If[AdisjExchange[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[AdisjExchange[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[AdisjExchange[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[AdisjExchange[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[AdisjExchange[[u, i, j]] >= 5, 
    Temp[[2, i, j]] = AdisjExchange[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdceVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdceVertex[[v]] = MultdceVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; AdceVertex[[s]] = AdisjExchange[[u]]; 
   MultdceVertex[[v]] = 1];
  ];
 If[u == 8, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent above-and-below-dressed exchange contributions found."]];
 ]
# Out:
# Loop 8 completed and 4 inequivalent above-and-below-dressed exchange\
#
# >    contributions found.

# %%
For[u = 1, u <= 4, u++, Print["CombExc[[", u, "]]=", AdceVertex[[u]], ";"]];
# Out:
# CombExc[[1]]={{1, 5}, {3, 6}, {2, 8}, {4, 7}};
# CombExc[[2]]={{1, 5}, {3, 7}, {2, 8}, {4, 6}};
# CombExc[[3]]={{1, 6}, {3, 8}, {4, 5}, {2, 7}};
# CombExc[[4]]={{1, 7}, {3, 8}, {4, 5}, {2, 6}};

# %%
For[u = 1, u <= 4, u++, Print["GGFMult[[", u, "]]=", MultdceVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=2;
# GGFMult[[2]]=2;
# GGFMult[[3]]=2;
# GGFMult[[4]]=2;

# %% [markdown]
# There are only $4$ inequivalent second-order above-and-below-dressed disjoint exchange diagrams with identical one-body vertices. The multiplicity check is fulfilled.

# %%
Sum[MultdceVertex[[u]], {u, 1, 4}]
# Out:
# 8

# %% [markdown]
# ## <font color=#FA8072>Disjoint Bogoliubov diagrams with dressed single-particle propagator on the antidiagonal</font>

# %% [markdown]
# Bogoliubov diagrams with unperturbed 1-body propagator on the diagonal are processed. Their initial number is $8$ in total.

# %% [markdown]
# ### <font color=#E9967A>Antidiagonally-dressed disjoint Bogoliubov diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent antidiagonally-dressed disjoint Bogoliubov contributions with non-identical vertices at second order remains equal to $8$.

# %%
For[u = 1, u <= 8, u++, Print["CombBogAntidiag[[", u, "]]=", AdisjBogoAntidiag[[u]], ";"]];
# Out:
# CombBogAntidiag[[1]]={{1, 3}, {2, 7}, {5, 6}, {4, 8}};
# CombBogAntidiag[[2]]={{1, 3}, {2, 8}, {5, 6}, {4, 7}};
# CombBogAntidiag[[3]]={{1, 4}, {3, 7}, {5, 6}, {2, 8}};
# CombBogAntidiag[[4]]={{1, 4}, {3, 8}, {5, 6}, {2, 7}};
# CombBogAntidiag[[5]]={{1, 7}, {2, 3}, {5, 6}, {4, 8}};
# CombBogAntidiag[[6]]={{1, 7}, {3, 8}, {5, 6}, {2, 4}};
# CombBogAntidiag[[7]]={{1, 8}, {3, 7}, {5, 6}, {2, 4}};
# CombBogAntidiag[[8]]={{1, 8}, {2, 3}, {5, 6}, {4, 7}};

# %%
For[u = 1, u <= 8, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;

# %% [markdown]
# There are only $8$ second-order antidiagonally-dressed disjoint Bogoliubov diagrams with non-identical one-body vertices. The multiplicity check is fulfilled by construction.

# %% [markdown]
# ### <font color=#E9967A>Antidiagonally-dressed disjoint Bogoliubov diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $4$ inequivalent fully-contracted terms corresponding to antidiagonally-dressed disjoint Bogoliubov diagrams are found.

# %%
AdcbaVertex = Table[0, {i, 1, 8}, {j, 1, 4}, {k, 1, 2}];
MultdcbaVertex = Table[0, {i, 1, 8}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 2}, {k, 1, 4}];

s = 1;
AdcbaVertex[[1]] = AdisjBogoAntidiag[[1]];
MultdcbaVertex[[1]] = 1;
For[u = 1, u <= 8, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = AdisjBogoAntidiag[[u, i, j]];
   If[AdisjBogoAntidiag[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[AdisjBogoAntidiag[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[AdisjBogoAntidiag[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[AdisjBogoAntidiag[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[AdisjBogoAntidiag[[u, i, j]] >= 5, 
    Temp[[2, i, j]] = AdisjBogoAntidiag[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdcbaVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdcbaVertex[[v]] = MultdcbaVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; 
   AdcbaVertex[[s]] = AdisjBogoAntidiag[[u]]; MultdcbaVertex[[v]] = 1];
  ];
 If[u == 8, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent antidiagonally-dressed disjoint Bogoliubov contributions found."]];
 ]
# Out:
# Loop 8 completed and 4 inequivalent antidiagonally-dressed disjoint\
#
# >    Bogoliubov contributions found.

# %%
For[u = 1, u <= 4, u++, Print["CombBogAntidiag[[", u, "]]=", AdcbaVertex[[u]], ";"]];
# Out:
# CombBogAntidiag[[1]]={{1, 3}, {2, 7}, {5, 6}, {4, 8}};
# CombBogAntidiag[[2]]={{1, 4}, {3, 7}, {5, 6}, {2, 8}};
# CombBogAntidiag[[3]]={{1, 4}, {3, 8}, {5, 6}, {2, 7}};
# CombBogAntidiag[[4]]={{1, 7}, {3, 8}, {5, 6}, {2, 4}};

# %%
For[u = 1, u <= 4, u++, Print["GGFMult[[", u, "]]=", MultdcbaVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=2;
# GGFMult[[2]]=2;
# GGFMult[[3]]=2;
# GGFMult[[4]]=2;

# %% [markdown]
# There are only $4$ inequivalent second-order antidiagonally-dressed disjoint Bogoliubov diagrams with identical one-body vertices. The multiplicity check is fulfilled.

# %%
Sum[MultdcbaVertex[[u]], {u, 1, 4}]
# Out:
# 8

# %% [markdown]
# ## <font color=#FA8072>Disjoint Bogoliubov diagrams with dressed single-particle propagator on the diagonal</font>

# %% [markdown]
# Bogoliubov diagrams with unperturbed 1-body propagator on the antidiagonal are processed. Their initial number is $8$ in total.

# %% [markdown]
# ### <font color=#E9967A>Diagonally-dressed disjoint Bogoliubov diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent diagonally-dressed disjoint Bogoliubov contributions with non-identical vertices at second order remains equal to $8$.

# %%
For[u = 1, u <= 8, u++, Print["CombBogDiag[[", u, "]]=", AdisjBogoDiag[[u]], ";"]];
# Out:
# CombBogDiag[[1]]={{1, 3}, {2, 5}, {4, 6}, {7, 8}};
# CombBogDiag[[2]]={{1, 3}, {2, 6}, {4, 5}, {7, 8}};
# CombBogDiag[[3]]={{1, 4}, {3, 5}, {2, 6}, {7, 8}};
# CombBogDiag[[4]]={{1, 4}, {3, 6}, {2, 5}, {7, 8}};
# CombBogDiag[[5]]={{1, 5}, {2, 3}, {4, 6}, {7, 8}};
# CombBogDiag[[6]]={{1, 5}, {3, 6}, {2, 4}, {7, 8}};
# CombBogDiag[[7]]={{1, 6}, {3, 5}, {2, 4}, {7, 8}};
# CombBogDiag[[8]]={{1, 6}, {2, 3}, {4, 5}, {7, 8}};

# %%
For[u = 1, u <= 8, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;

# %% [markdown]
# There are only $8$ second-order diagonally-dressed disjoint Bogoliubov diagrams with non-identical one-body vertices. The multiplicity check is fulfilled by construction.

# %% [markdown]
# ### <font color=#E9967A>Diagonally-dressed disjoint Bogoliubov diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $4$ inequivalent fully-contracted terms corresponding to diagonally-dressed disjoint Bogoliubov diagrams are found.

# %%
AdcbdVertex = Table[0, {i, 1, 8}, {j, 1, 4}, {k, 1, 2}];
MultdcbdVertex = Table[0, {i, 1, 8}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 2}, {k, 1, 4}];

s = 1;
AdcbdVertex[[1]] = AdisjBogoDiag[[1]];
MultdcbdVertex[[1]] = 1;
For[u = 1, u <= 8, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = AdisjBogoDiag[[u, i, j]];
   If[AdisjBogoDiag[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[AdisjBogoDiag[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[AdisjBogoDiag[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[AdisjBogoDiag[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[AdisjBogoDiag[[u, i, j]] >= 5, 
    Temp[[2, i, j]] = AdisjBogoDiag[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdcbdVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdcbdVertex[[v]] = MultdcbdVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; AdcbdVertex[[s]] = AdisjBogoDiag[[u]]; 
   MultdcbdVertex[[v]] = 1];
  ];
 If[u == 8, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent diagonally-dressed disjoint Bogoliubov contributions found."]];
 ]
# Out:
# Loop 8 completed and 4 inequivalent diagonally-dressed disjoint Bogoliubov\
#
# >    contributions found.

# %%
For[u = 1, u <= 4, u++, Print["CombBogDiag[[", u, "]]=", AdcbdVertex[[u]], ";"]];
# Out:
# CombBogDiag[[1]]={{1, 3}, {2, 5}, {4, 6}, {7, 8}};
# CombBogDiag[[2]]={{1, 4}, {3, 5}, {2, 6}, {7, 8}};
# CombBogDiag[[3]]={{1, 4}, {3, 6}, {2, 5}, {7, 8}};
# CombBogDiag[[4]]={{1, 5}, {3, 6}, {2, 4}, {7, 8}};

# %%
For[u = 1, u <= 4, u++, Print["GGFMult[[", u, "]]=", MultdcbdVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=2;
# GGFMult[[2]]=2;
# GGFMult[[3]]=2;
# GGFMult[[4]]=2;

# %% [markdown]
# There are only $4$ inequivalent second-order diagonally-dressed disjoint Bogoliubov diagrams with identical one-body vertices. The multiplicity check is fulfilled.

# %%
Sum[MultdcbdVertex[[u]], {u, 1, 4}]
# Out:
# 8

# %% [markdown]
# ## <font color=#FA8072>Disjoint Bogoliubov diagrams with dressed single-particle propagators on the diagonal and the antidiagonal</font>

# %% [markdown]
# Bogoliubov diagrams with perturbed 1-body propagators on the diagonal and antidiagonal are processed. Their initial number is $8$ in total.

# %% [markdown]
# ### <font color=#E9967A>Diagonally-and-antidiagonally-dressed disjoint Bogoliubov diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent diagonally-and-antidiagonally-dressed disjoint Bogoliubov contributions with non-identical vertices at second order remains equal to $8$.

# %%
For[u = 1, u <= 8, u++, Print["CombBog[[", u, "]]=", AdisjBogoliubov[[u]], ";"]];
# Out:
# CombBog[[1]]={{1, 5}, {3, 7}, {2, 6}, {4, 8}};
# CombBog[[2]]={{1, 5}, {3, 8}, {2, 6}, {4, 7}};
# CombBog[[3]]={{1, 6}, {3, 7}, {2, 5}, {4, 8}};
# CombBog[[4]]={{1, 6}, {3, 8}, {2, 5}, {4, 7}};
# CombBog[[5]]={{1, 7}, {3, 5}, {4, 6}, {2, 8}};
# CombBog[[6]]={{1, 7}, {3, 6}, {4, 5}, {2, 8}};
# CombBog[[7]]={{1, 8}, {3, 5}, {4, 6}, {2, 7}};
# CombBog[[8]]={{1, 8}, {3, 6}, {4, 5}, {2, 7}};

# %%
For[u = 1, u <= 8, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;

# %% [markdown]
# There are only $8$ second-order diagonally-and-antidiagonally-dressed disjoint Bogoliubov diagrams with non-identical one-body vertices. The multiplicity check is fulfilled by construction.

# %% [markdown]
# ### <font color=#E9967A>Diagonally-and-antidiagonally-dressed disjoint Bogoliubov diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $4$ inequivalent fully-contracted terms corresponding to diagonally-and-antidiagonally-dressed disjoint Bogoliubov diagrams are found.

# %%
AdcbVertex = Table[0, {i, 1, 8}, {j, 1, 4}, {k, 1, 2}];
MultdcbVertex = Table[0, {i, 1, 8}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 2}, {k, 1, 4}];

s = 1;
AdcbVertex[[1]] = AdisjBogoliubov[[1]];
MultdcbVertex[[1]] = 1;
For[u = 1, u <= 8, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = AdisjBogoliubov[[u, i, j]];
   If[AdisjBogoliubov[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[AdisjBogoliubov[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[AdisjBogoliubov[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[AdisjBogoliubov[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[AdisjBogoliubov[[u, i, j]] >= 5, 
    Temp[[2, i, j]] = AdisjBogoliubov[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdcbVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdcbVertex[[v]] = MultdcbVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; AdcbVertex[[s]] = AdisjBogoliubov[[u]]; 
   MultdcbVertex[[v]] = 1];
  ];
 If[u == 8, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent diagonally-and-antidiagonally-dressed Bogoliubov contributions found."]];
 ]
# Out:
# Loop 8 completed and 4 inequivalent diagonally-and-antidiagonally-dressed\
#
# >    Bogoliubov contributions found.

# %%
For[u = 1, u <= 4, u++, Print["CombBog[[", u, "]]=", AdcbVertex[[u]], ";"]];
# Out:
# CombBog[[1]]={{1, 5}, {3, 7}, {2, 6}, {4, 8}};
# CombBog[[2]]={{1, 5}, {3, 8}, {2, 6}, {4, 7}};
# CombBog[[3]]={{1, 6}, {3, 7}, {2, 5}, {4, 8}};
# CombBog[[4]]={{1, 6}, {3, 8}, {2, 5}, {4, 7}};

# %%
For[u = 1, u <= 4, u++, Print["GGFMult[[", u, "]]=", MultdcbVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=2;
# GGFMult[[2]]=2;
# GGFMult[[3]]=2;
# GGFMult[[4]]=2;

# %% [markdown]
# There are only $8$ inequivalent second-order diagonally-and-antidiagonally-dressed disjoint Bogoliubov diagrams with identical one-body vertices. The multiplicity check is fulfilled.

# %%
Sum[MultdcbVertex[[u]], {u, 1, 4}]
# Out:
# 8

# %% [markdown]
# # <font color=#71797E>Disconnected Diagrams</font>

# %% [markdown]
# For each Nambu component of the one-body potential, second-order disconnected diagrams are $33$ in total. The filtration process is necessary, if the two vertices belong to the same Nambu component.

# %%
Adisc = Table[0, {i, 1, 105}, {j, 1, 4}, {k, 1, 2}];
l = 1;
For[i = 1, i <= 105, i++, 
 SelfBinding12 = False;
 SelfBinding34 = False;
 Bridge13 = False;
 Bridge14 = False;
 Bridge23 = False;
 Bridge24 = False;
 For[j = 1, j <= 4, j++,
  If[Acombsort[[i, j]] == {1, 3}  , Bridge13 = True];
  If[Acombsort[[i, j]] == {1, 4}  , Bridge14 = True];
  If[Acombsort[[i, j]] == {2, 3}  , Bridge23 = True];
  If[Acombsort[[i, j]] == {2, 4}  , Bridge24 = True];
  If[Acombsort[[i, j]] == {1, 2}  , SelfBinding12 = True];
  If[Acombsort[[i, j]] == {3, 4}  , SelfBinding34 = True];
  ];
 If[SelfBinding12 == True || SelfBinding34 == True, 
  Adisc[[l]] = Acombsort[[i]]; l++];
 If[Bridge13 == True && Bridge24 == True, Adisc[[l]] = Acombsort[[i]];
   l++];
 If[Bridge23 == True && Bridge14 == True, Adisc[[l]] = Acombsort[[i]];
   l++];
 If[i == 105, 
  Print["Loop ", i, " completed and ", l - 1, 
   " disconnected contributions found."] ];]
# Out:
# Loop 105 completed and 33 disconnected contributions found.

# %% [markdown]
# ### <font color=#E9967A>Disconnected diagrams with non-identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are distinct, no vertex exchange is possible. Additionally, since single-particle index transpositions within each one-body vertex are forbidden, no filtration process is necessary. Thus, the number of inequivalent disconnected contributions with non-identical vertices at second order remains equal to $33$.

# %%
For[u = 1, u <= 33, u++, Print["CombDisc[[", u, "]]=", Adisc[[u]], ";"]];
# Out:
# CombDisc[[1]]={{1, 2}, {3, 4}, {5, 6}, {7, 8}};
# CombDisc[[2]]={{1, 2}, {3, 4}, {5, 7}, {6, 8}};
# CombDisc[[3]]={{1, 2}, {3, 4}, {5, 8}, {6, 7}};
# CombDisc[[4]]={{1, 2}, {3, 5}, {4, 6}, {7, 8}};
# CombDisc[[5]]={{1, 2}, {3, 5}, {4, 7}, {6, 8}};
# CombDisc[[6]]={{1, 2}, {3, 5}, {4, 8}, {6, 7}};
# CombDisc[[7]]={{1, 2}, {3, 6}, {4, 5}, {7, 8}};
# CombDisc[[8]]={{1, 2}, {3, 6}, {5, 7}, {4, 8}};
# CombDisc[[9]]={{1, 2}, {3, 6}, {5, 8}, {4, 7}};
# CombDisc[[10]]={{1, 2}, {3, 7}, {5, 6}, {4, 8}};
# CombDisc[[11]]={{1, 2}, {3, 7}, {4, 5}, {6, 8}};
# CombDisc[[12]]={{1, 2}, {3, 7}, {5, 8}, {4, 6}};
# CombDisc[[13]]={{1, 2}, {3, 8}, {5, 6}, {4, 7}};
# CombDisc[[14]]={{1, 2}, {3, 8}, {5, 7}, {4, 6}};
# CombDisc[[15]]={{1, 2}, {3, 8}, {4, 5}, {6, 7}};
# CombDisc[[16]]={{1, 3}, {2, 4}, {5, 6}, {7, 8}};
# CombDisc[[17]]={{1, 3}, {2, 4}, {5, 7}, {6, 8}};
# CombDisc[[18]]={{1, 3}, {2, 4}, {5, 8}, {6, 7}};
# CombDisc[[19]]={{1, 4}, {2, 3}, {5, 6}, {7, 8}};
# CombDisc[[20]]={{1, 4}, {2, 3}, {5, 7}, {6, 8}};
# CombDisc[[21]]={{1, 4}, {2, 3}, {5, 8}, {6, 7}};
# CombDisc[[22]]={{1, 5}, {3, 4}, {2, 6}, {7, 8}};
# CombDisc[[23]]={{1, 5}, {3, 4}, {2, 7}, {6, 8}};
# CombDisc[[24]]={{1, 5}, {3, 4}, {2, 8}, {6, 7}};
# CombDisc[[25]]={{1, 6}, {3, 4}, {2, 5}, {7, 8}};
# CombDisc[[26]]={{1, 6}, {3, 4}, {5, 7}, {2, 8}};
# CombDisc[[27]]={{1, 6}, {3, 4}, {5, 8}, {2, 7}};
# CombDisc[[28]]={{1, 7}, {3, 4}, {5, 6}, {2, 8}};
# CombDisc[[29]]={{1, 7}, {3, 4}, {2, 5}, {6, 8}};
# CombDisc[[30]]={{1, 7}, {3, 4}, {5, 8}, {2, 6}};
# CombDisc[[31]]={{1, 8}, {3, 4}, {5, 6}, {2, 7}};
# CombDisc[[32]]={{1, 8}, {3, 4}, {5, 7}, {2, 6}};
# CombDisc[[33]]={{1, 8}, {3, 4}, {2, 5}, {6, 7}};

# %%
For[u = 1, u <= 33, u++, Print["GGFMult[[", u, "]]=", 1, ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=1;
# GGFMult[[5]]=1;
# GGFMult[[6]]=1;
# GGFMult[[7]]=1;
# GGFMult[[8]]=1;
# GGFMult[[9]]=1;
# GGFMult[[10]]=1;
# GGFMult[[11]]=1;
# GGFMult[[12]]=1;
# GGFMult[[13]]=1;
# GGFMult[[14]]=1;
# GGFMult[[15]]=1;
# GGFMult[[16]]=1;
# GGFMult[[17]]=1;
# GGFMult[[18]]=1;
# GGFMult[[19]]=1;
# GGFMult[[20]]=1;
# GGFMult[[21]]=1;
# GGFMult[[22]]=1;
# GGFMult[[23]]=1;
# GGFMult[[24]]=1;
# GGFMult[[25]]=1;
# GGFMult[[26]]=1;
# GGFMult[[27]]=1;
# GGFMult[[28]]=1;
# GGFMult[[29]]=1;
# GGFMult[[30]]=1;
# GGFMult[[31]]=1;
# GGFMult[[32]]=1;
# GGFMult[[33]]=1;

# %% [markdown]
# There are only $33$ second-order disconnected diagrams with non-identical one-body vertex. The multiplicity check is fulfilled.

# %% [markdown]
# ### <font color=#E9967A>Disconnected diagrams with identical one-body vertices</font>

# %% [markdown]
# Depending on the components of the one-body potential into play, symmetry rules may apply and reduce the total number of fully-contracted terms. When the multiplied Nambu components of the one-body potential are identical, vertex exchange is possible, hence the filtration process is necessary. Specifically, fully contracted terms which are mapped one another by the single-particle-index transposition $e \mapsto g \wedge f \mapsto h$ are equivalent, thus one of the two can be dropped, incrementing the associated multiplicity by unity. In the end of the process, $21$ inequivalent fully-contracted terms corresponding to disconnected diagrams are found.

# %%
AdVertex = Table[0, {i, 1, 33}, {j, 1, 4}, {k, 1, 2}];
MultdVertex = Table[0, {i, 1, 33}];
Ifrepeat = False;
Temp = Table[0, {i, 1, 2}, {j, 1, 4}, {k, 1, 2}];
IfTemp = Table[0, {i, 1, 2}, {k, 1, 4}];

s = 1;
AdVertex[[1]] = Adisc[[1]];
MultdVertex[[1]] = 1;
For[u = 1, u <= 33, u++,
 For[i = 1, i <= 4, i++,
  For[j = 1, j <= 2, j++,
   Temp[[1, i, j]] = Adisc[[u, i, j]];
   If[Adisc[[u, i, j]] == 1, Temp[[2, i, j]] = 3];
   If[Adisc[[u, i, j]] == 2, Temp[[2, i, j]] = 4];
   If[Adisc[[u, i, j]] == 3, Temp[[2, i, j]] = 1];
   If[Adisc[[u, i, j]] == 4, Temp[[2, i, j]] = 2];
   If[Adisc[[u, i, j]] >= 5, Temp[[2, i, j]] = Adisc[[u, i, j]]];
   ]];
 For[i = 1, i <= 2, i++,
  If[Temp[[i, 1, 1]] > Temp[[i, 1, 2]], t2 = Temp[[i, 1, 2]]; 
   t1 = Temp[[i, 1, 1]]; Temp[[i, 1, 1]] = t2; Temp[[i, 1, 2]] = t1];
  If[Temp[[i, 2, 1]] > Temp[[i, 2, 2]], t2 = Temp[[i, 2, 2]]; 
   t1 = Temp[[i, 2, 1]]; Temp[[i, 2, 1]] = t2; Temp[[i, 2, 2]] = t1];
  If[Temp[[i, 3, 1]] > Temp[[i, 3, 2]], t2 = Temp[[i, 3, 2]]; 
   t1 = Temp[[i, 3, 1]]; Temp[[i, 3, 1]] = t2; Temp[[i, 3, 2]] = t1];
  If[Temp[[i, 4, 1]] > Temp[[i, 4, 2]], t2 = Temp[[i, 4, 2]]; 
   t1 = Temp[[i, 4, 1]]; Temp[[i, 4, 1]] = t2; Temp[[i, 4, 2]] = t1];];
 Ifrepeat = False;
 If[u != 1,
  For[v = 1, v <= s, v++,
   Vrepeat = False;
   For[i = 1, i <= 2, i++,
    For[j = 1, j <= 4, j++,
     IfTemp[[i, j]] = 0;
     ]];
   For[i = 1, i <= 4, i++,
    For[j = 1, j <= 2, j++,
      For[k = 1, k <= 4, k++,
        If[AdVertex[[v, i]] == Temp[[j, k]], IfTemp[[j, k]] = 1;];
        ];];];
   If[IfTemp[[1, 1]] + IfTemp[[1, 2]] + IfTemp[[1, 3]] + 
      IfTemp[[1, 4]] == 4, Vrepeat = True;];
   If[IfTemp[[2, 1]] + IfTemp[[2, 2]] + IfTemp[[2, 3]] + 
      IfTemp[[2, 4]] == 4, Vrepeat = True;];
   If[Vrepeat == True, Ifrepeat = True; 
    MultdVertex[[v]] = MultdVertex[[v]] + 1];
   ];
  If[Ifrepeat == False , s++; AdVertex[[s]] = Adisc[[u]]; 
   MultdVertex[[v]] = 1];
  ];
 If[u == 33, 
  Print["Loop ", u, " completed and ", s, 
   " inequivalent disconnected contributions found."]];
 ]
# Out:
# Loop 33 completed and 21 inequivalent disconnected contributions found.

# %%
For[u = 1, u <= 21, u++, Print["CombDisc[[", u, "]]=", AdVertex[[u]], ";"]];
# Out:
# CombDisc[[1]]={{1, 2}, {3, 4}, {5, 6}, {7, 8}};
# CombDisc[[2]]={{1, 2}, {3, 4}, {5, 7}, {6, 8}};
# CombDisc[[3]]={{1, 2}, {3, 4}, {5, 8}, {6, 7}};
# CombDisc[[4]]={{1, 2}, {3, 5}, {4, 6}, {7, 8}};
# CombDisc[[5]]={{1, 2}, {3, 5}, {4, 7}, {6, 8}};
# CombDisc[[6]]={{1, 2}, {3, 5}, {4, 8}, {6, 7}};
# CombDisc[[7]]={{1, 2}, {3, 6}, {4, 5}, {7, 8}};
# CombDisc[[8]]={{1, 2}, {3, 6}, {5, 7}, {4, 8}};
# CombDisc[[9]]={{1, 2}, {3, 6}, {5, 8}, {4, 7}};
# CombDisc[[10]]={{1, 2}, {3, 7}, {5, 6}, {4, 8}};
# CombDisc[[11]]={{1, 2}, {3, 7}, {4, 5}, {6, 8}};
# CombDisc[[12]]={{1, 2}, {3, 7}, {5, 8}, {4, 6}};
# CombDisc[[13]]={{1, 2}, {3, 8}, {5, 6}, {4, 7}};
# CombDisc[[14]]={{1, 2}, {3, 8}, {5, 7}, {4, 6}};
# CombDisc[[15]]={{1, 2}, {3, 8}, {4, 5}, {6, 7}};
# CombDisc[[16]]={{1, 3}, {2, 4}, {5, 6}, {7, 8}};
# CombDisc[[17]]={{1, 3}, {2, 4}, {5, 7}, {6, 8}};
# CombDisc[[18]]={{1, 3}, {2, 4}, {5, 8}, {6, 7}};
# CombDisc[[19]]={{1, 4}, {2, 3}, {5, 6}, {7, 8}};
# CombDisc[[20]]={{1, 4}, {2, 3}, {5, 7}, {6, 8}};
# CombDisc[[21]]={{1, 4}, {2, 3}, {5, 8}, {6, 7}};

# %%
For[u = 1, u <= 21, u++, Print["GGFMult[[", u, "]]=", MultdVertex[[u]], ";"]];
# Out:
# GGFMult[[1]]=1;
# GGFMult[[2]]=1;
# GGFMult[[3]]=1;
# GGFMult[[4]]=2;
# GGFMult[[5]]=2;
# GGFMult[[6]]=2;
# GGFMult[[7]]=2;
# GGFMult[[8]]=2;
# GGFMult[[9]]=2;
# GGFMult[[10]]=2;
# GGFMult[[11]]=2;
# GGFMult[[12]]=2;
# GGFMult[[13]]=2;
# GGFMult[[14]]=2;
# GGFMult[[15]]=2;
# GGFMult[[16]]=1;
# GGFMult[[17]]=1;
# GGFMult[[18]]=1;
# GGFMult[[19]]=1;
# GGFMult[[20]]=1;
# GGFMult[[21]]=1;

# %% [markdown]
# There are only $21$ inequivalent second-order disconnected diagrams with identical one-body vertex. The multiplicity check is fulfilled.

# %%
Sum[MultdVertex[[u]], {u, 1, 21}]
# Out:
# 33
